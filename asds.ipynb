# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow as op
from matplotlib.pyplot import figure as fig
from skimage.io import imread
from skimage.color import rgb2gray

# %%
img = imread("lena.png")
op(img,"gray")

# %%
l,w=img.shape
for i in range(l):
    for j in range(w):
        img[i,j] = np.(img[i,j]+1)
op(img,"gray")
